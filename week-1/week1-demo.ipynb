# %%
import pandas as pd

# %%
df = pd.read_csv('s3://week1-demo/egrid2016.csv')
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     221             file_obj = fsspec.open(
# --> 222                 filepath_or_buffer, mode=mode or "rb", **(storage_options or {})
#     223             ).open()
#
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/site-packages/fsspec/core.py in open(self)
#     132         """
# --> 133         out = self.__enter__()
#     134         closer = out.close
#
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/site-packages/fsspec/core.py in __enter__(self)
#     100
# --> 101         f = self.fs.open(self.path, mode=mode)
#     102
#
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
# ...

# %%
df.head()
