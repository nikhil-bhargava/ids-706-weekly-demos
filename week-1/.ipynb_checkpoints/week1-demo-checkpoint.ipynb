# %%
import pandas as pd

# %%
df = pd.read_csv('s3://week1-demo/egrid2016.csv')
# Out:
# ---------------------------------------------------------------------------
# ParsingError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/site-packages/botocore/configloader.py in raw_config_parse(config_filename, parse_subsections)
#     148         try:
# --> 149             cp.read([path])
#     150         except (six.moves.configparser.Error, UnicodeDecodeError):
#
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/configparser.py in read(self, filenames, encoding)
#     695                 with open(filename, encoding=encoding) as fp:
# --> 696                     self._read(fp, filename)
#     697             except OSError:
#
# ~/opt/anaconda3/envs/ids-706/lib/python3.7/configparser.py in _read(self, fp, fpname)
#    1109         if e:
# -> 1110             raise e
#    1111
#
# ParsingError: Source contains parsing errors: '/Users/nikhilbhargava/.aws/credentials'
# 	[line  2]: 'aws_\n'
#
# ...

# %%
df.head()
